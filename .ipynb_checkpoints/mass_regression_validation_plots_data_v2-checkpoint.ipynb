# %%
import numpy as np
import os, glob
import matplotlib.pyplot as plt
import mplhep as hep
plt.style.use([hep.style.ROOT, hep.style.firamath])
import pickle
from matplotlib.colors import LinearSegmentedColormap
channel_list = ["Tracks_pt", "Tracks_dZSig", "Tracks_d0Sig", "ECAL_energy",
"HBHE_energy", "Pix_1", "Pix_2", "Pix_3", "Pix_4", "Tib_1", "Tib_2",
"Tib_3", "Tib_4", "Tob_1", "Tob_2", "Tob_3", "Tob_4", "Tob_5",
"Tob_6", "Tid_1", "Tec_1", "Tec_2", "Tec_3"]


# Define the CMS color scheme
cms_colors = [
    (0.00, '#FFFFFF'),  # White
    (0.33, '#005EB8'),  # Blue
    (0.66, '#FFDD00'),  # Yellow
    (1.00, '#FF0000')   # red
]

# Create the CMS colormap
cms_cmap = LinearSegmentedColormap.from_list('CMS', cms_colors)
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-e929jzhs because the default path (/uscms/home/bbbam/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# Matplotlib is building the font cache; this may take a moment.

# %%
m0_scale    = 14
m0_min      = 3.6
m0_max      = 14
mtrue_bins = np.arange(m0_min, m0_max, .4)
mae_min  =0
mae_max  = 10.5
mae_bins = np.arange(mae_min, mae_max, .5)
mre_bins = np.arange(0, 1.05, .05)
mass_bins = np.arange(3600,14000,400)/1000.

# %%
### ---- mass_trainer_aToTauTau_m1p2To17p2_unphysical_over_populated_less_data_lowerUnPhysical_range ---

# %%
# data_file = "../mass_trainer_aToTauTau_m1p2To17p2_unphysical_over_populated_less_data_lowerUnPhysical_range/INFERENCE_DATA/5_channels_aToTauTau_pT30To180_with_mass1p2To17p2_less_data_lowerUnphy_range_PTscale0.02_ECALscale0_HCALscale1_AOD_m0o14.0_ResNet_blocks3_mae_loss_epochs15_BatchSize1024_from20_ntrain6645760_nval560128_run0/epoch32_val_pseudoscalar_mae1.7824_inference_data.pkl"
# infile = open(f"{data_file}", "rb")
# data = pickle.load(infile)
# print(f"loaded data file ------>  {data_file}")
# infile.close()

# m_true_ = data["m_true"]
# m_pred_ = data["m_pred"]
# mae_ = data["mae"]
# mre_ = data["mre"]

# %%
## H to A to 4tau signal sample Mass =10 Gev

# %%
# data_file = "../data/huber_0.5_epoch4_val_pseudoscalar_mae2.0267_inference_data.pkl"
data_file = "../mass_trainer_aToTauTau_m1p2To17p2_unphysical_over_populated_less_data_lowerUnPhysical_range/INFERENCE_DATA/INFERENCE_5_channels_Signal_M10_pT30To180/epoch32_val_pseudoscalar_mae1.8953_inference_data.pkl"
infile = open(f"{data_file}", "rb")
data = pickle.load(infile)
print(f"loaded data file ------>  {data_file}")
infile.close()

m_true_ = data["m_true"]
m_pred_ = data["m_pred"]
mae_ = data["mae"]
mre_ = data["mre"]

data_file = "../conversion_plot_scripts/plot_signal_image_data_pkl/data_for_validation_H_AATo4Tau_hadronic_dR0p4_M10_a_jet_mass_pt.pkl"
infile = open(f"{data_file}", "rb")
data = pickle.load(infile)
print(f"loaded data file ------>  {data_file}")
infile.close()
jet_mass=data["jet_mass"]
a_mass=data["a_mass"]
a_pt=data["a_pt"]
jet_pt=data["jet_pt"]
# Out:
# loaded data file ------>  ../mass_trainer_aToTauTau_m1p2To17p2_unphysical_over_populated_less_data_lowerUnPhysical_range/INFERENCE_DATA/INFERENCE_5_channels_Signal_M10_pT30To180/epoch32_val_pseudoscalar_mae1.8953_inference_data.pkl
# loaded data file ------>  ../conversion_plot_scripts/plot_signal_image_data_pkl/data_for_validation_H_AATo4Tau_hadronic_dR0p4_M10_a_jet_mass_pt.pkl

# %%
# out_dir = f"PLOTS_for_massregressor_Validation_Upsilon"
# save = 0
# if save: 
#     if not os.path.isdir(out_dir):
#         os.makedirs(out_dir)

# %%
# Check 1D m_pred
# Extebded version
fig, ax = plt.subplots(figsize=(15,15))
plt.hist(m_true_, range=(m0_min-1.2,m0_max+1.2), bins=len(np.arange(m0_min-1.2,m0_max+1.2,0.4)), histtype='step', label=r'$\mathrm{m_{true}}$', linestyle='-', color='blue', linewidth=2)
plt.hist(m_pred_, range=(m0_min-1.2,m0_max+1.2), bins=len(np.arange(m0_min-1.2,m0_max+1.2,0.4)), histtype='step', label=r'$\mathrm{m_{pred}}$', linestyle='-', color='red', linewidth=2)
plt.hist(jet_mass, range=(m0_min-1.2,m0_max+1.2), bins=len(np.arange(m0_min-1.2,m0_max+1.2,0.4)), histtype='step', label=r'$\mathrm{m_{jet}}$', linestyle='--', color='black', linewidth=2)
plt.xlim(m0_min-1.2,m0_max+1.2)
plt.xticks(np.arange(m0_min-1.2,m0_max+1.2,0.8))
plt.grid(color='r', linestyle='--', linewidth=.1)
plt.xlabel('Mass [GeV]')
plt.ylabel('Events/ 0.4 [GeV]')
# plt.title(r'$\mathrm{m_{true}}$, $\mathrm{m_{pred}}$ masses',size=25)
plt.legend(loc='upper right')
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# if save: plt.savefig('%s/%d_mtru_mpred_hist_full.png'%(out_dir, epoch), bbox_inches='tight',dpi=300, facecolor = "w")
plt.show()

# # Truncated version
# fig, ax = plt.subplots(figsize=(20,20))
# plt.hist(m_true_, range=(m0_min-0.4,m0_max+0.4), bins=len(np.arange(m0_min-0.4,m0_max+0.4,0.4)), histtype='step', label=r'$\mathrm{m_{true}}$', linestyle='-', color='blue', linewidth=2,log=1)
# plt.hist(m_pred_, range=(m0_min-0.4,m0_max+0.4), bins=len(np.arange(m0_min-0.4,m0_max+0.4,0.4)), histtype='step', label=r'$\mathrm{m_{pred}}$', linestyle='-', color='red', linewidth=2,log=1)
# plt.xlim(m0_min-0.4,m0_max+0.4)
# plt.xticks(np.arange(m0_min,m0_max+0.4,0.4),size=15)
# plt.grid(color='r', linestyle='--', linewidth=.1)
# plt.xlabel('Mass [GeV]')
# plt.ylabel('Events/ 0.4 [GeV]' )
# # plt.title(r'$\mathrm{m_{true}}$, $\mathrm{m_{pred}}$ masses', size=25)
# plt.legend(loc='upper right')
# hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# # if save: plt.savefig('%s/%d_mtru_mpred_hist_truncate.png'%(out_dir, epoch), bbox_inches='tight',dpi=300, facecolor = "w")
# plt.show()

# %%
## Upsilon to Tau Tau validation sample

# %%
# data_file = "../data/huber_0.5_epoch4_val_pseudoscalar_mae2.0267_inference_data.pkl"
data_file = "../mass_trainer_aToTauTau_m1p2To17p2_unphysical_over_populated_less_data_lowerUnPhysical_range/INFERENCE_DATA/INFERENCE_5_channels_upsilon_pT30To180/epoch32_val_pseudoscalar_mae1.9442_inference_data.pkl"
infile = open(f"{data_file}", "rb")
data = pickle.load(infile)
print(f"loaded data file ------>  {data_file}")
infile.close()

m_true_ = data["m_true"]
m_pred_ = data["m_pred"]
mae_ = data["mae"]
mre_ = data["mre"]

data_file = "../conversion_plot_scripts/plots_from_pq_unbiased_data_pkl/IMG_Upsilon_ToTauTau_Hadronic_tauDR0p4_m3p6To14_dataset_validation/data_for_validation_upsilonToTauTau_hadronic_dR0p4_a_jet_mass_pt.pkl"
infile = open(f"{data_file}", "rb")
data = pickle.load(infile)
print(f"loaded data file ------>  {data_file}")
infile.close()
jet_mass=data["jet_mass"]
a_mass=data["a_mass"]
a_pt=data["a_pt"]
jet_pt=data["jet_pt"]
# Out:
# loaded data file ------>  ../mass_trainer_aToTauTau_m1p2To17p2_unphysical_over_populated_less_data_lowerUnPhysical_range/INFERENCE_DATA/INFERENCE_5_channels_upsilon_pT30To180/epoch32_val_pseudoscalar_mae1.9442_inference_data.pkl
# loaded data file ------>  ../conversion_plot_scripts/plots_from_pq_unbiased_data_pkl/IMG_Upsilon_ToTauTau_Hadronic_tauDR0p4_m3p6To14_dataset_validation/data_for_validation_upsilonToTauTau_hadronic_dR0p4_a_jet_mass_pt.pkl

# %%
# Check 1D m_pred
# Extebded version
fig, ax = plt.subplots(figsize=(15,15))
plt.hist(m_true_, range=(m0_min-1.2,m0_max+1.2), bins=len(np.arange(m0_min-1.2,m0_max+1.2,0.4)), histtype='step', label=r'$\mathrm{m_{true}}$', linestyle='-', color='blue', linewidth=2)
plt.hist(m_pred_, range=(m0_min-1.2,m0_max+1.2), bins=len(np.arange(m0_min-1.2,m0_max+1.2,0.4)), histtype='step', label=r'$\mathrm{m_{pred}}$', linestyle='-', color='red', linewidth=2)
plt.hist(jet_mass, range=(m0_min-1.2,m0_max+1.2), bins=len(np.arange(m0_min-1.2,m0_max+1.2,0.4)), histtype='step', label=r'$\mathrm{m_{jet}}$', linestyle='--', color='black', linewidth=2)
plt.xlim(m0_min-1.2,m0_max+1.2)
plt.xticks(np.arange(m0_min-1.2,m0_max+1.2,0.8))
plt.grid(color='r', linestyle='--', linewidth=.1)
plt.xlabel('Mass [GeV]')
plt.ylabel('Events/ 0.4 [GeV]')
# plt.title(r'$\mathrm{m_{true}}$, $\mathrm{m_{pred}}$ masses',size=25)
plt.legend(loc='upper right')
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# if save: plt.savefig('%s/%d_mtru_mpred_hist_full.png'%(out_dir, epoch), bbox_inches='tight',dpi=300, facecolor = "w")
plt.show()

# %%
### ---- mass_trainer_aToTauTau_m3p6To17p2_with_newModel_noBN ---

# %%
## H to A to 4tau signal sample Mass =10 Gev

# %%
# data_file = "../data/huber_0.5_epoch4_val_pseudoscalar_mae2.0267_inference_data.pkl"
data_file = "../mass_trainer_aToTauTau_m3p6To17p2_with_newModel_noBN/INFERENCE_DATA/INFERENCE_5_channels_Signal_M10_pT30To180/epoch12_val_pseudoscalar_mae1.8222_inference_data.pkl"
infile = open(f"{data_file}", "rb")
data = pickle.load(infile)
print(f"loaded data file ------>  {data_file}")
infile.close()

m_true_ = data["m_true"]
m_pred_ = data["m_pred"]
mae_ = data["mae"]
mre_ = data["mre"]

data_file = "../conversion_plot_scripts/plot_signal_image_data_pkl/data_for_validation_H_AATo4Tau_hadronic_dR0p4_M10_a_jet_mass_pt.pkl"
infile = open(f"{data_file}", "rb")
data = pickle.load(infile)
print(f"loaded data file ------>  {data_file}")
infile.close()
jet_mass=data["jet_mass"]
a_mass=data["a_mass"]
a_pt=data["a_pt"]
jet_pt=data["jet_pt"]
# Out:
# loaded data file ------>  ../mass_trainer_aToTauTau_m3p6To17p2_with_newModel_noBN/INFERENCE_DATA/INFERENCE_5_channels_Signal_M10_pT30To180/epoch12_val_pseudoscalar_mae1.8222_inference_data.pkl
# loaded data file ------>  ../conversion_plot_scripts/plot_signal_image_data_pkl/data_for_validation_H_AATo4Tau_hadronic_dR0p4_M10_a_jet_mass_pt.pkl

# %%
# Check 1D m_pred
# Extebded version
fig, ax = plt.subplots(figsize=(15,15))
plt.hist(m_true_, range=(m0_min-1.2,m0_max+1.2), bins=len(np.arange(m0_min-1.2,m0_max+1.2,0.4)), histtype='step', label=r'$\mathrm{m_{true}}$', linestyle='-', color='blue', linewidth=2)
plt.hist(m_pred_, range=(m0_min-1.2,m0_max+1.2), bins=len(np.arange(m0_min-1.2,m0_max+1.2,0.4)), histtype='step', label=r'$\mathrm{m_{pred}}$', linestyle='-', color='red', linewidth=2)
plt.hist(jet_mass, range=(m0_min-1.2,m0_max+1.2), bins=len(np.arange(m0_min-1.2,m0_max+1.2,0.4)), histtype='step', label=r'$\mathrm{m_{jet}}$', linestyle='--', color='black', linewidth=2)
plt.xlim(m0_min-1.2,m0_max+1.2)
plt.xticks(np.arange(m0_min-1.2,m0_max+1.2,0.8))
plt.grid(color='r', linestyle='--', linewidth=.1)
plt.xlabel('Mass [GeV]')
plt.ylabel('Events/ 0.4 [GeV]')
# plt.title(r'$\mathrm{m_{true}}$, $\mathrm{m_{pred}}$ masses',size=25)
plt.legend(loc='upper right')
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# if save: plt.savefig('%s/%d_mtru_mpred_hist_full.png'%(out_dir, epoch), bbox_inches='tight',dpi=300, facecolor = "w")
plt.show()

# # Truncated version
# fig, ax = plt.subplots(figsize=(20,20))
# plt.hist(m_true_, range=(m0_min-0.4,m0_max+0.4), bins=len(np.arange(m0_min-0.4,m0_max+0.4,0.4)), histtype='step', label=r'$\mathrm{m_{true}}$', linestyle='-', color='blue', linewidth=2,log=1)
# plt.hist(m_pred_, range=(m0_min-0.4,m0_max+0.4), bins=len(np.arange(m0_min-0.4,m0_max+0.4,0.4)), histtype='step', label=r'$\mathrm{m_{pred}}$', linestyle='-', color='red', linewidth=2,log=1)
# plt.xlim(m0_min-0.4,m0_max+0.4)
# plt.xticks(np.arange(m0_min,m0_max+0.4,0.4),size=15)
# plt.grid(color='r', linestyle='--', linewidth=.1)
# plt.xlabel('Mass [GeV]')
# plt.ylabel('Events/ 0.4 [GeV]' )
# # plt.title(r'$\mathrm{m_{true}}$, $\mathrm{m_{pred}}$ masses', size=25)
# plt.legend(loc='upper right')
# hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# # if save: plt.savefig('%s/%d_mtru_mpred_hist_truncate.png'%(out_dir, epoch), bbox_inches='tight',dpi=300, facecolor = "w")
# plt.show()

# %%
## Upsilon to Tau Tau validation sample

# %%
# data_file = "../data/huber_0.5_epoch4_val_pseudoscalar_mae2.0267_inference_data.pkl"
data_file = "../mass_trainer_aToTauTau_m3p6To17p2_with_newModel_noBN/INFERENCE_DATA/INFERENCE_5_channels_Upsilon1S_pT30To180/epoch10_val_pseudoscalar_mae1.8726_inference_data.pkl"
infile = open(f"{data_file}", "rb")
data = pickle.load(infile)
print(f"loaded data file ------>  {data_file}")
infile.close()

m_true_ = data["m_true"]
m_pred_ = data["m_pred"]
mae_ = data["mae"]
mre_ = data["mre"]

data_file = "../conversion_plot_scripts/plots_from_pq_unbiased_data_pkl/IMG_Upsilon_ToTauTau_Hadronic_tauDR0p4_m3p6To14_dataset_validation/data_for_validation_upsilonToTauTau_hadronic_dR0p4_a_jet_mass_pt.pkl"
infile = open(f"{data_file}", "rb")
data = pickle.load(infile)
print(f"loaded data file ------>  {data_file}")
infile.close()
jet_mass=data["jet_mass"]
a_mass=data["a_mass"]
a_pt=data["a_pt"]
jet_pt=data["jet_pt"]
# Out:
# loaded data file ------>  ../mass_trainer_aToTauTau_m3p6To17p2_with_newModel_noBN/INFERENCE_DATA/INFERENCE_5_channels_Upsilon1S_pT30To180/epoch10_val_pseudoscalar_mae1.8726_inference_data.pkl
# loaded data file ------>  ../conversion_plot_scripts/plots_from_pq_unbiased_data_pkl/IMG_Upsilon_ToTauTau_Hadronic_tauDR0p4_m3p6To14_dataset_validation/data_for_validation_upsilonToTauTau_hadronic_dR0p4_a_jet_mass_pt.pkl

# %%
# Check 1D m_pred
# Extebded version
fig, ax = plt.subplots(figsize=(15,15))
plt.hist(m_true_, range=(m0_min-1.2,m0_max+1.2), bins=len(np.arange(m0_min-1.2,m0_max+1.2,0.4)), histtype='step', label=r'$\mathrm{m_{true}}$', linestyle='-', color='blue', linewidth=2)
plt.hist(m_pred_, range=(m0_min-1.2,m0_max+1.2), bins=len(np.arange(m0_min-1.2,m0_max+1.2,0.4)), histtype='step', label=r'$\mathrm{m_{pred}}$', linestyle='-', color='red', linewidth=2)
plt.hist(jet_mass, range=(m0_min-1.2,m0_max+1.2), bins=len(np.arange(m0_min-1.2,m0_max+1.2,0.4)), histtype='step', label=r'$\mathrm{m_{jet}}$', linestyle='--', color='black', linewidth=2)
plt.xlim(m0_min-1.2,m0_max+1.2)
plt.xticks(np.arange(m0_min-1.2,m0_max+1.2,0.8))
plt.grid(color='r', linestyle='--', linewidth=.1)
plt.xlabel('Mass [GeV]')
plt.ylabel('Events/ 0.4 [GeV]')
# plt.title(r'$\mathrm{m_{true}}$, $\mathrm{m_{pred}}$ masses',size=25)
plt.legend(loc='upper right')
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# if save: plt.savefig('%s/%d_mtru_mpred_hist_full.png'%(out_dir, epoch), bbox_inches='tight',dpi=300, facecolor = "w")
plt.show()
