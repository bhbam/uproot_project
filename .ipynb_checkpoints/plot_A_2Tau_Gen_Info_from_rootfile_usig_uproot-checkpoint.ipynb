# %%
import uproot
import awkward as ak
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import mplhep as hep
import os, glob
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import mplhep as hep
plt.style.use([hep.style.ROOT, hep.style.firamath])
from matplotlib.colors import LinearSegmentedColormap
# Define the CMS color scheme
cms_colors = [
    (0.00, '#FFFFFF'),  # White
    (0.33, '#005EB8'),  # Blue
    (0.66, '#FFDD00'),  # Yellow
    (1.00, '#FF0000')   # red
]

# Create the CMS colormap
cms_cmap = LinearSegmentedColormap.from_list('CMS', cms_colors)

# %%
# file = uproot.open("../analysis/gen_information_A_2Tau/CMSSW_10_6_20/src/Gen/genInfo_only_A_2Tau_dR0p4_train.root")
# file = uproot.open("../analysis/gen_information_A_2Tau/CMSSW_10_6_20/src/Gen/genInfo_only_U_2Tau_dR0p4_train.root")
# file = uproot.open("../analysis/gen_information_A_2Tau/CMSSW_10_6_20/src/Gen/genInfo_only_H_AA_2Tau_dR0p4_train.root")
# 
RHTree = file["fevt/RHTree"]
# RHTree.keys()
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[45], line 5
#       1 # file = uproot.open("../analysis/gen_information_A_2Tau/CMSSW_10_6_20/src/Gen/genInfo_only_A_2Tau_dR0p4_train.root")
#       2 # file = uproot.open("../analysis/gen_information_A_2Tau/CMSSW_10_6_20/src/Gen/genInfo_only_U_2Tau_dR0p4_train.root")
#       3 # file = uproot.open("../analysis/gen_information_A_2Tau/CMSSW_10_6_20/src/Gen/genInfo_only_H_AA_2Tau_dR0p4_train.root")
#       4 file = uproot.open("../analysis/mass_regreesion_ntuples/CMSSW_10_6_20/src/MLAnalyzer/output.root")
# ----> 5 RHTree = file["fevt/RHTree"]
#       6 # RHTree.keys()
#
# File /opt/conda/lib/python3.8/site-packages/uproot/reading.py:2090, in ReadOnlyDirectory.__getitem__(self, where)
#    2088     else:
#    2089         last = step
# -> 2090         step = step[item]
#    2092 elif isinstance(step, uproot.behaviors.TBranch.HasBranches):
#    2093     return step["/".join(items[i:])]
#
# File /opt/conda/lib/python3.8/site-packages/uproot/reading.py:2107, in ReadOnlyDirectory.__getitem__(self, where)
#    2104     return step
#    2106 else:
# -> 2107     return self.key(where).get()
#
# File /opt/conda/lib/python3.8/site-packages/uproot/reading.py:2057, in ReadOnlyDirectory.key(self, where)
#    2055     return last
#    2056 elif cycle is None:
# -> 2057     raise uproot.KeyInFileError(
#    2058         item, cycle="any", keys=self.keys(), file_path=self._file.file_path
#    2059     )
#    2060 else:
#    2061     raise uproot.KeyInFileError(
#    2062         item, cycle=cycle, keys=self.keys(), file_path=self._file.file_path
#    2063     )
#
# KeyInFileError: not found: 'fevt' (with any cycle number)
#
#     Available keys: (none!)
#
# in file ../analysis/mass_regreesion_ntuples/CMSSW_10_6_20/src/MLAnalyzer/output.root

# %%
GenA1_invariant = RHTree.arrays(["GenA1_inv"],"GenA1_inv > -111",library="pd")['GenA1_inv']
jetM = RHTree.arrays(["jetM"],"jetM > -111",library="pd")['jetM']
fig, ax = plt.subplots(figsize=(15,15))
plt.hist(GenA1_invariant,bins=np.arange(3.,17,0.4),color='grey',alpha=0.5,label="Invariant mass",density =0,log=1)
plt.hist(jetM,bins=np.arange(3.,20,0.4),histtype='step',linestyle='--',linewidth=2, color='red',label="Jet mass",density=0,log=1)
# plt.xticks(np.arange(3.6,17,0.8))
plt.legend()
plt.ylabel("Events")
plt.xlabel("gen A (invariant) [GeV]")
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# if save: plt.savefig('%s/gen_A_mass_hist.png'%(out_dir),  bbox_inches='tight', dpi=300, facecolor = "w")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.8/site-packages/uproot/language/python.py:378, in PythonLanguage.free_symbols(self, expression, keys, aliases, file_path, object_path)
#     377 try:
# --> 378     return list(
#     379         _walk_ast_yield_symbols(
#     380             node, keys, aliases, self._functions, self._getter
#     381         )
#     382     )
#     383 except KeyError as err:
#
# File /opt/conda/lib/python3.8/site-packages/uproot/language/python.py:90, in _walk_ast_yield_symbols(node, keys, aliases, functions, getter)
#      89         x = getattr(node, field_name)
# ---> 90         yield from _walk_ast_yield_symbols(x, keys, aliases, functions, getter)
#      92 elif isinstance(node, list):
#
# File /opt/conda/lib/python3.8/site-packages/uproot/language/python.py:94, in _walk_ast_yield_symbols(node, keys, aliases, functions, getter)
#      93     for x in node:
# ---> 94         yield from _walk_ast_yield_symbols(x, keys, aliases, functions, getter)
#      96 else:
#
# File /opt/conda/lib/python3.8/site-packages/uproot/language/python.py:90, in _walk_ast_yield_symbols(node, keys, aliases, functions, getter)
#      89         x = getattr(node, field_name)
# ---> 90         yield from _walk_ast_yield_symbols(x, keys, aliases, functions, getter)
#      92 elif isinstance(node, list):
#
# File /opt/conda/lib/python3.8/site-packages/uproot/language/python.py:73, in _walk_ast_yield_symbols(node, keys, aliases, functions, getter)
#      72     else:
# ---> 73         raise KeyError(node.id)
#      75 elif isinstance(node, ast.Attribute):
#
# KeyError: 'GenA1_inv'
#
# The above exception was the direct cause of the following exception:
#
# KeyInFileError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 GenA1_invariant = RHTree.arrays(["GenA1_inv"],"GenA1_inv > -111",library="pd")['GenA1_inv']
#       2 jetM = RHTree.arrays(["jetM"],"jetM > -111",library="pd")['jetM']
#       3 fig, ax = plt.subplots(figsize=(15,15))
#
# File /opt/conda/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:1232, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, how)
#    1229         return None
#    1231 aliases = _regularize_aliases(self, aliases)
# -> 1232 arrays, expression_context, branchid_interpretation = _regularize_expressions(
#    1233     self,
#    1234     expressions,
#    1235     cut,
#    1236     filter_name,
#    1237     filter_typename,
#    1238     filter_branch,
#    1239     keys,
#    1240     aliases,
#    1241     language,
#    1242     get_from_cache,
#    1243 )
#    1245 ranges_or_baskets = []
#    1246 checked = set()
#
# File /opt/conda/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:3299, in _regularize_expressions(hasbranches, expressions, cut, filter_name, filter_typename, filter_branch, keys, aliases, language, get_from_cache)
#    3297 for expression, interp in items:
#    3298     if interp is None:
# -> 3299         _regularize_expression(
#    3300             hasbranches,
#    3301             expression,
#    3302             keys,
#    3303             aliases,
#    3304             language,
#    3305             get_from_cache,
#    3306             arrays,
#    3307             expression_context,
#    3308             branchid_interpretation,
#    3309             (),
#    3310             False,
#    3311             None,
#    3312         )
#    3313     else:
#    3314         branch = hasbranches[expression]
#
# File /opt/conda/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:3167, in _regularize_expression(hasbranches, expression, keys, aliases, language, get_from_cache, arrays, expression_context, branchid_interpretation, symbol_path, is_cut, rename)
#    3165 is_jagged = False
#    3166 expression_branches = []
# -> 3167 for symbol in language.free_symbols(
#    3168     to_compute,
#    3169     keys,
#    3170     aliases,
#    3171     hasbranches.file.file_path,
#    3172     hasbranches.object_path,
#    3173 ):
#    3174     if symbol in symbol_path:
#    3175         raise ValueError(
#    3176             """symbol {} is recursively defined with aliases:
#    3177
#    (...)
#    3185             )
#    3186         )
#
# File /opt/conda/lib/python3.8/site-packages/uproot/language/python.py:384, in PythonLanguage.free_symbols(self, expression, keys, aliases, file_path, object_path)
#     378     return list(
#     379         _walk_ast_yield_symbols(
#     380             node, keys, aliases, self._functions, self._getter
#     381         )
#     382     )
#     383 except KeyError as err:
# --> 384     raise uproot.KeyInFileError(
#     385         err.args[0], file_path=file_path, object_path=object_path
#     386     ) from err
#
# KeyInFileError: not found: 'GenA1_inv'
# in file root://cmseos.fnal.gov//store/group/lpcml/bbbam/Ntuples/gen_HToAATo4Tau_Hadronic_tauDR0p4_M10_ctau0To3_eta0To2p4_pythia8_2018UL/HtoAATo4Tau_Hadronic_tauDR0p4_M10_eta0To2p4_pythia8_signal/230725_041228/0000/output_90.root
# in object /fevt/RHTree;22

# %%
Tau1_pt = RHTree.arrays(["Tau1_pt"],"Tau1_pt > -111",library="pd")['Tau1_pt']
Tau2_pt = RHTree.arrays(["Tau2_pt"],"Tau2_pt > -111",library="pd")['Tau2_pt']

fig, ax = plt.subplots(figsize=(15,15))
plt.hist(Tau1_pt,bins=np.arange(30,200,5),histtype='step', color='red',label="Tau1 pt")
plt.hist(Tau2_pt,bins=np.arange(30,200,5),histtype='step', color='b',label="Tau2 pt")

plt.xticks(np.arange(20,200,20))
plt.legend()
plt.ylabel("Events")
plt.xlabel("gen Tau pt [GeV]")
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# if save: plt.savefig('%s/gen_Tau_pt_hist.png'%(out_dir),  bbox_inches='tight', dpi=300, facecolor = "w")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.8/site-packages/uproot/language/python.py:378, in PythonLanguage.free_symbols(self, expression, keys, aliases, file_path, object_path)
#     377 try:
# --> 378     return list(
#     379         _walk_ast_yield_symbols(
#     380             node, keys, aliases, self._functions, self._getter
#     381         )
#     382     )
#     383 except KeyError as err:
#
# File /opt/conda/lib/python3.8/site-packages/uproot/language/python.py:90, in _walk_ast_yield_symbols(node, keys, aliases, functions, getter)
#      89         x = getattr(node, field_name)
# ---> 90         yield from _walk_ast_yield_symbols(x, keys, aliases, functions, getter)
#      92 elif isinstance(node, list):
#
# File /opt/conda/lib/python3.8/site-packages/uproot/language/python.py:94, in _walk_ast_yield_symbols(node, keys, aliases, functions, getter)
#      93     for x in node:
# ---> 94         yield from _walk_ast_yield_symbols(x, keys, aliases, functions, getter)
#      96 else:
#
# File /opt/conda/lib/python3.8/site-packages/uproot/language/python.py:90, in _walk_ast_yield_symbols(node, keys, aliases, functions, getter)
#      89         x = getattr(node, field_name)
# ---> 90         yield from _walk_ast_yield_symbols(x, keys, aliases, functions, getter)
#      92 elif isinstance(node, list):
#
# File /opt/conda/lib/python3.8/site-packages/uproot/language/python.py:73, in _walk_ast_yield_symbols(node, keys, aliases, functions, getter)
#      72     else:
# ---> 73         raise KeyError(node.id)
#      75 elif isinstance(node, ast.Attribute):
#
# KeyError: 'Tau1_pt'
#
# The above exception was the direct cause of the following exception:
#
# KeyInFileError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 Tau1_pt = RHTree.arrays(["Tau1_pt"],"Tau1_pt > -111",library="pd")['Tau1_pt']
#       2 Tau2_pt = RHTree.arrays(["Tau2_pt"],"Tau2_pt > -111",library="pd")['Tau2_pt']
#       4 fig, ax = plt.subplots(figsize=(15,15))
#
# File /opt/conda/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:1232, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, how)
#    1229         return None
#    1231 aliases = _regularize_aliases(self, aliases)
# -> 1232 arrays, expression_context, branchid_interpretation = _regularize_expressions(
#    1233     self,
#    1234     expressions,
#    1235     cut,
#    1236     filter_name,
#    1237     filter_typename,
#    1238     filter_branch,
#    1239     keys,
#    1240     aliases,
#    1241     language,
#    1242     get_from_cache,
#    1243 )
#    1245 ranges_or_baskets = []
#    1246 checked = set()
#
# File /opt/conda/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:3299, in _regularize_expressions(hasbranches, expressions, cut, filter_name, filter_typename, filter_branch, keys, aliases, language, get_from_cache)
#    3297 for expression, interp in items:
#    3298     if interp is None:
# -> 3299         _regularize_expression(
#    3300             hasbranches,
#    3301             expression,
#    3302             keys,
#    3303             aliases,
#    3304             language,
#    3305             get_from_cache,
#    3306             arrays,
#    3307             expression_context,
#    3308             branchid_interpretation,
#    3309             (),
#    3310             False,
#    3311             None,
#    3312         )
#    3313     else:
#    3314         branch = hasbranches[expression]
#
# File /opt/conda/lib/python3.8/site-packages/uproot/behaviors/TBranch.py:3167, in _regularize_expression(hasbranches, expression, keys, aliases, language, get_from_cache, arrays, expression_context, branchid_interpretation, symbol_path, is_cut, rename)
#    3165 is_jagged = False
#    3166 expression_branches = []
# -> 3167 for symbol in language.free_symbols(
#    3168     to_compute,
#    3169     keys,
#    3170     aliases,
#    3171     hasbranches.file.file_path,
#    3172     hasbranches.object_path,
#    3173 ):
#    3174     if symbol in symbol_path:
#    3175         raise ValueError(
#    3176             """symbol {} is recursively defined with aliases:
#    3177
#    (...)
#    3185             )
#    3186         )
#
# File /opt/conda/lib/python3.8/site-packages/uproot/language/python.py:384, in PythonLanguage.free_symbols(self, expression, keys, aliases, file_path, object_path)
#     378     return list(
#     379         _walk_ast_yield_symbols(
#     380             node, keys, aliases, self._functions, self._getter
#     381         )
#     382     )
#     383 except KeyError as err:
# --> 384     raise uproot.KeyInFileError(
#     385         err.args[0], file_path=file_path, object_path=object_path
#     386     ) from err
#
# KeyInFileError: not found: 'Tau1_pt'
# in file root://cmseos.fnal.gov//store/group/lpcml/bbbam/Ntuples/gen_HToAATo4Tau_Hadronic_tauDR0p4_M10_ctau0To3_eta0To2p4_pythia8_2018UL/HtoAATo4Tau_Hadronic_tauDR0p4_M10_eta0To2p4_pythia8_signal/230725_041228/0000/output_90.root
# in object /fevt/RHTree;22

# %%
# file=uproot.open("root://cmseos.fnal.gov//store/group/lpcml/bbbam/Ntuples/gen_HToAATo4Tau_Hadronic_tauDR0p4_M10_ctau0To3_eta0To2p4_pythia8_2018UL/HtoAATo4Tau_Hadronic_tauDR0p4_M10_eta0To2p4_pythia8_signal/230725_041228/0000/output_90.root")
file=uproot.open("root://cmseos.fnal.gov//store/group/lpcml/bbbam/Ntuples/aToTauTau_Hadronic_tauDR0p4_m3p6To16_pT30To180_ctau0To3_eta0To1p4_pythia8_unbiased4ML_dataset_1/aToTauTau_Hadronic_tauDR0p4_m3p6To14_dataset_1_unbaise_false_ntuples/230416_184752/0000/output_90.root")
file = uproot.open("../analysis/mass_regreesion_ntuples/CMSSW_10_6_20/src/MLAnalyzer/output.root")
RHTree = file["fevt/RHTree"]
# RHTree.keys()

# %%
GenA1_invariant = RHTree.arrays(["a_m"],"a_m > -111",library="pd")['a_m']
jetM = RHTree.arrays(["jetM"],"jetM > -111",library="pd")['jetM']
fig, ax = plt.subplots(figsize=(15,15))
plt.hist(GenA1_invariant,bins=np.arange(3.,17,0.4),color='grey',alpha=0.5,label="Invariant mass",density =0,log=1)
plt.hist(jetM,bins=np.arange(3.,20,0.4),histtype='step',linestyle='--',linewidth=2, color='red',label="Jet mass",density=0,log=1)
# plt.xticks(np.arange(3.6,17,0.8))
plt.legend()
plt.ylabel("Events")
plt.xlabel("gen A (invariant) [GeV]")
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# if save: plt.savefig('%s/gen_A_mass_hist.png'%(out_dir),  bbox_inches='tight', dpi=300, facecolor = "w")
plt.show()

# %%
Tau1_pt = RHTree.arrays(["Tau1pT"],"Tau1pT > -111",library="pd")['Tau1pT']
Tau2_pt = RHTree.arrays(["Tau2pT"],"Tau2pT > -111",library="pd")['Tau2pT']

fig, ax = plt.subplots(figsize=(15,15))
plt.hist(Tau1_pt,bins=np.arange(30,200,5),histtype='step', color='red',label="Tau1 pt")
plt.hist(Tau2_pt,bins=np.arange(30,200,5),histtype='step', color='b',label="Tau2 pt")

plt.xticks(np.arange(20,200,20))
plt.legend()
plt.ylabel("Events")
plt.xlabel("gen Tau pt [GeV]")
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# if save: plt.savefig('%s/gen_Tau_pt_hist.png'%(out_dir),  bbox_inches='tight', dpi=300, facecolor = "w")
plt.show()

# %%
Tau1pT = RHTree.arrays(["Tau1pT"],"Tau1pT > -111",library="pd")['Tau1pT']
Tau2pT = RHTree.arrays(["Tau2pT"],"Tau2pT > -111",library="pd")['Tau2pT']
import pandas as pd
TaupT = pd.concat([Tau1pT, Tau2pT])

fig, ax = plt.subplots(figsize=(15,15))
plt.hist(TaupT,bins=np.arange(30,200,5),histtype='step', color='red',label="Tau pt")

plt.xticks(np.arange(20,200,20))
plt.legend()
plt.ylabel("Events")
plt.xlabel("gen Tau pt [GeV]")
hep.cms.label(llabel="Simulation Preliminary", rlabel="13 TeV", loc=0, ax=ax)
# if save: plt.savefig('%s/gen_Tau_pt_hist.png'%(out_dir),  bbox_inches='tight', dpi=300, facecolor = "w")
plt.show()
